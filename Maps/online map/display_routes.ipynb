# %%
# !pip3 install -r requirements_online.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from _display_routes import create_map, DATA_DIR_PATH
import datetime


# This notebook only create a map object using the create_map implemented in `_display_routes` and displays it
map = create_map(
    # Path to a JSON file containing the routes, see README.md or `exemple_route.json` to understand the format.
    routes_file_path=DATA_DIR_PATH / "exemple_routes.json",
    # Path to a CSV file containing the service times, see README.md or the `exemple_points_service_time.csv` 
    # to understnad the format.
    service_times_file_path=DATA_DIR_PATH / "exemple_points_service_time.csv",
    # Wether the animation loops.
    loop=False,
    # How long does the animation goes on.
    duration=datetime.timedelta(seconds=15),
    # Lists of indices of the routes to show, if empty or None shows all of them.
    show=[],
    
)
map

# The map bellow is animated: to launch the animation click the play button or use the arrow buttons on the 
# side when the animation is paused to control precisely the time.

# The time start today at 08:00, the time displayed takes into account the travel times and the service times
# but for technical reasons it is not completely accurate: except at the start and at the end of the route, 
# the position of the vehicle and the time displayed are slightly off.

# You can control the frame rate  with the fps flisder but it is very buggy.

# You can put the map in fullscreen mode with the top right corner button.

# It takes a bit of time to display the time because it has to do some request to the demo OSRM server which
# is not the fastest.

# You can customise the map even more in `_display_routes`, but if you make any modification there you need to 
# restart the kernel to take those modifications into account.
# Out:
# /Users/chaikovm/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
# ...
